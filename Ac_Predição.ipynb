# %% [markdown]
# <a href="https://colab.research.google.com/github/tottithome/Linguagem-R/blob/main/Ac_Predi%C3%A7%C3%A3o.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import matplotlib.pyplot as plt

def grafico(x:list,y:list):
    plt.plot(x,y,marker='o',linestyle='-')
    plt.xlabel('Ano')
    plt.ylabel('Vendas')
    plt.title('Vendas de Pirozhki ao longo dos anos')
    plt.grid(True)
    plt.show()

#criando um gráfico a partir de uma tabela
x_ano = [2010,2011,2012,2014,2017,2018,2019]
y_vendas  = [723,814,905,1087,1360,1451,1542]
grafico(x_ano,y_vendas)

#Qual coeficiente angular
coef_angular = (814 - 723) / (2011 - 2010)
print("Coeficiente angular:", coef_angular)

#calcular vendas do ano desejado
ano_desejado = int(input("Ano desejado para a previsão das vendas: "))
x_ano.append(ano_desejado)

vendas_desejado = (ano_desejado - 2010) * coef_angular + 723
y_vendas.append(vendas_desejado)

print(vendas_desejado)

grafico(x_ano,y_vendas)

#Se a tendência continuar as vendas vão continuar crescendo, mas se considerarmos que no novo lugar ele não tem a mesma popularidade do ano anterior
#talvez tenha umpouco mais de dificuldade no ano de 2021, já no ano de 2023 acreditamos que as vendas seram bem melhores por já estar instalado no local,
#tendo certo conhecimento da região, além de melhorar sua popularidade o que vai alavancar as vendas ainda mais.
#2021 - 1724 vendas
#2023 - 1906 vendas
# Out:
# Coeficiente angular: 91.0
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-2-8282717aa850> in <cell line: 21>()
#      19
#      20 #calcular vendas do ano desejado
# ---> 21 ano_desejado = int(input("Ano desejado para a previsão das vendas: "))
#      22 x_ano.append(ano_desejado)
#      23
#
# /usr/local/lib/python3.10/dist-packages/ipykernel/kernelbase.py in raw_input(self, prompt)
#     849                 "raw_input was called, but this frontend does not support input requests."
#     850             )
# --> 851         return self._input_request(str(prompt),
#     852             self._parent_ident,
#     853             self._parent_header,
#
# /usr/local/lib/python3.10/dist-packages/ipykernel/kernelbase.py in _input_request(self, prompt, ident, parent, password)
#     893             except KeyboardInterrupt:
# ...
